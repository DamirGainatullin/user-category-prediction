# %%
# !pip install lightgbm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import lightgbm as lgb
from sklearn.metrics import f1_score, precision_score, recall_score
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import random

RND = 42
np.random.seed(RND)
random.seed(RND)

# %%
df = pd.read_csv('train.csv')
sample_submission = pd.read_csv('sample_submission.csv')
df['order_completed_at'] = pd.to_datetime(df['order_completed_at'])
df.head()
# Out:
#    user_id  order_completed_at  cart
# 0        2 2015-03-22 09:25:46   399
# 1        2 2015-03-22 09:25:46    14
# 2        2 2015-03-22 09:25:46   198
# 3        2 2015-03-22 09:25:46    88
# 4        2 2015-03-22 09:25:46   157

# %%
#EDA

# %%
df.describe(include='all')
# Out:
#             user_id             order_completed_at          cart
# count  3.123064e+06                        3123064  3.123064e+06
# mean   7.253373e+03  2020-04-09 01:17:00.182836992  2.273235e+02
# min    0.000000e+00            2015-03-22 09:25:46  0.000000e+00
# 25%    2.884000e+03            2020-02-03 06:03:43  4.200000e+01
# 50%    6.055000e+03            2020-05-19 06:35:20  1.460000e+02
# 75%    1.117200e+04            2020-07-14 04:50:22  3.990000e+02
# max    1.999900e+04            2020-09-03 23:45:45  8.800000e+02
# std    5.337838e+03                            NaN  2.112867e+02

# %%
print(df.shape)
print(df.isna().sum().sum())
# Out:
# (3123064, 3)
# 0

# %%
order_freq = df['user_id'].value_counts()
plt.figure(figsize=(10, 6))
plt.hist(order_freq, bins=50)
plt.xlabel('Пользователи')
plt.ylabel('Частота')
plt.title('Распределение количества заказов по пользователям')
plt.show()

# %%
carts_freq = df['cart'].value_counts()
plt.figure(figsize=(10, 6))
plt.hist(carts_freq, bins=50)
plt.xlabel('Категории товара')
plt.ylabel('Частота')
plt.title('Распределение количества заказов по категориям товаров')
plt.show()

# %%
# Создадим тестовую выборку: для каждого пользователя будут только фактические покупки из его последнего заказа 

df = df.sort_values(['user_id', 'order_completed_at'])

last_orders = df.groupby('user_id')['order_completed_at'].max().reset_index().rename(columns={'order_completed_at': 'last_order_completed_at'})

df = df.merge(last_orders, on='user_id', how='left')
df['is_test'] = (df['order_completed_at'] == df['last_order_completed_at']).astype(int)

train = df[df['is_test'] == 0].copy()
val  = df[df['is_test'] == 1].copy()

print(f"Train shape: {train.shape}")
print(f"Test shape:  {val.shape}")
# Out:
# Train shape: (2841987, 5)
# Test shape:  (281077, 5)

# %%
val.head()
# Out:
#     user_id  order_completed_at  cart last_order_completed_at  is_test
# 33        0 2020-09-02 07:38:25   803     2020-09-02 07:38:25        1
# 34        0 2020-09-02 07:38:25   170     2020-09-02 07:38:25        1
# 35        0 2020-09-02 07:38:25    84     2020-09-02 07:38:25        1
# 36        0 2020-09-02 07:38:25    61     2020-09-02 07:38:25        1
# 37        0 2020-09-02 07:38:25   440     2020-09-02 07:38:25        1

# %%
train = train.drop(columns=['is_test', 'last_order_completed_at'])
val  = val.drop(columns=['is_test', 'last_order_completed_at'])
train_with_dates = train.copy()
train_pos = train.drop(columns=['order_completed_at'])
train_pos.head()
# Out:
#    user_id  cart
# 0        0    20
# 1        0    82
# 2        0   441
# 3        0    57
# 4        0    14

# %%
def build_user_item_matrix(train_pos):
    """Создает разреженную матрицу user × item"""
    users = train_pos['user_id'].unique()
    carts = train_pos['cart'].unique()

    user2idx = {u: i for i, u in enumerate(users)}
    cart2idx = {c: i for i, c in enumerate(carts)}
    idx2cart = {i: c for c, i in cart2idx.items()}

    rows = train_pos['user_id'].map(user2idx).to_numpy()
    cols = train_pos['cart'].map(cart2idx).to_numpy()
    data = np.ones(len(train_pos), dtype=np.int8)

    user_item_csr = csr_matrix((data, (rows, cols)), shape=(len(users), len(carts)))
    return user_item_csr, user2idx, cart2idx, idx2cart

# %%
def compute_item_neighbors(user_item_csr, idx2cart, top_k=50):
    """Вычисляет top-k похожих товаров с помощью cosine similarity"""
    item_user_csr = user_item_csr.T.tocsr()

    nbrs = NearestNeighbors(n_neighbors=top_k, metric='cosine', algorithm='brute', n_jobs=-1)
    nbrs.fit(item_user_csr)
    _, indices = nbrs.kneighbors(item_user_csr)

    item_neighbors = {}
    for item_idx, neigh_idxs in enumerate(indices):
        similar = [idx2cart[j] for j in neigh_idxs if j != item_idx]
        item_neighbors[idx2cart[item_idx]] = similar

    return item_neighbors

# %%
def generate_negative_samples(train_pos, item_neighbors, ratio=1.0):
    """Создает негативные примеры с учетом похожих товаров"""
    user_to_bought = train_pos.groupby('user_id')['cart'].apply(set).to_dict()
    all_carts = set(train_pos['cart'].unique())
    neg_samples = []

    for user, bought in user_to_bought.items():
        n_pos = len(bought)
        n_neg = int(n_pos * ratio)

        candidate_set = set()
        for b in bought:
            candidate_set.update(item_neighbors.get(b, []))
        candidate_set -= bought

        # fallback, если мало кандидатов
        if len(candidate_set) < n_neg:
            extra = list(all_carts - bought - candidate_set)
            candidate_set.update(random.sample(extra, min(len(extra), n_neg - len(candidate_set))))

        sampled = random.sample(candidate_set, min(len(candidate_set), n_neg))
        for c in sampled:
            neg_samples.append({'user_id': user, 'cart': c, 'target': 0})

    return pd.DataFrame(neg_samples)

# %%
# Создаем матрицу
user_item_csr, user2idx, cart2idx, idx2cart = build_user_item_matrix(train_pos)

# Находим соседей
item_neighbors = compute_item_neighbors(user_item_csr, idx2cart, top_k=50)

# Генерируем негативы
train_neg = generate_negative_samples(train_pos, item_neighbors, ratio=1.0)

# Объединяем
train_pos = train_pos.copy()
train_pos['target'] = 1
train_full = pd.concat([train_pos, train_neg], ignore_index=True)

print("Итоговый баланс классов:")
print(train_full['target'].value_counts())
# Out:
# C:\Users\Redmi\AppData\Local\Temp\ipykernel_18624\3222012761.py:21: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   sampled = random.sample(candidate_set, min(len(candidate_set), n_neg))
# Итоговый баланс классов:
# target
# 1    2841987
# 0    1031269
# Name: count, dtype: int64

# %%
# analyze how change distribution after negative sampling
user_freq = train_full['user_id'].value_counts()
plt.figure(figsize=(10, 6))
plt.hist(user_freq, bins=50)
plt.xlabel('Категории товара')
plt.ylabel('Частота')
plt.title('Распределение количества заказов по пользователям')
plt.show()

# %%
cart_freq = train_full['cart'].value_counts()
plt.figure(figsize=(10, 6))
plt.hist(user_freq, bins=50)
plt.xlabel('Категории товара')
plt.ylabel('Частота')
plt.title('Распределение количества заказов по категориям товаров')
plt.show()

# %%
print(train_pos.shape)
print(train_with_dates.shape)
print(train_full.shape)
# Out:
# (2841987, 3)
# (2841987, 3)
# (3873256, 3)

# %%
user_cart_count = (train_with_dates.groupby(['user_id', 'cart']).size().reset_index(name='user_cart_count')) # how much user ordered each cart
cart_popularity = (train_with_dates.groupby(['cart'])['user_id'].nunique()).reset_index(name='cart_popularity') # how much people ordered each cart
total_users = train_with_dates['user_id'].nunique()
cart_popularity['cart_popularity'] = cart_popularity['cart_popularity'] / total_users

train_full = train_full.merge(user_cart_count, how='left', on=['user_id', 'cart'])
train_full = train_full.merge(cart_popularity, how='left', on='cart')
train_full['user_cart_count'] = train_full['user_cart_count'].fillna(0)

val_ = val.merge(user_cart_count, how='left', on=['user_id', 'cart'])
val_ = val_.merge(cart_popularity, how='left', on='cart')
val_['user_cart_count'] = val_['user_cart_count'].fillna(0)

train_full.head()
# Out:
#    user_id  cart  target  user_cart_count  cart_popularity
# 0        0    20       1              1.0          0.29530
# 1        0    82       1              2.0          0.37465
# 2        0   441       1              2.0          0.26310
# 3        0    57       1              2.0          0.81680
# 4        0    14       1              2.0          0.76365
